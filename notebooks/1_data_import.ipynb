# %%
print("=" * 60)
print("DATA IMPORT SUMMARY")
print("=" * 60)
print(f"\nOriginal rows: {df.shape[0]}")
print(f"Cleaned rows: {df_clean.shape[0]}")
print(f"Columns: {df_clean.shape[1]}")
print(f"\nColumn names:")
for i, col in enumerate(df_clean.columns, 1):
    print(f"  {i}. {col} ({df_clean[col].dtype})")

print(f"\nTarget Variable: 'price'")
print(f"Features: {df_clean.shape[1] - 1}")
print(f"\nData types:")
print(df_clean.dtypes)

print("\n✓ Data import completed successfully!")
# Out:
# ...
# DATA IMPORT SUMMARY
# ...
#
# Original rows: 13320
# Cleaned rows: 12791
# Columns: 9
#
# Column names:
#   1. area_type (str)
#   2. availability (str)
#   3. location (str)
#   4. size (str)
#   5. society (str)
#   6. total_sqft (float64)
#   7. bath (float64)
#   8. balcony (float64)
#   9. price (float64)
#
# Target Variable: 'price'
# Features: 8
#
# Data types:
# area_type           str
# availability        str
# location            str
# size                str
# society             str
# total_sqft      float64
# bath            float64
# balcony         float64
# price           float64
# dtype: object
#
# ✓ Data import completed successfully!

# %% [markdown]
# ## Step 4: Data Summary

# %%
# Try to connect to database and load data
try:
    db = MySQLConnector()
    db.connect()
    print("✓ Database connection successful!")
    
    # Check if table exists
    result = db.execute_query("SHOW TABLES LIKE 'property_listings'")
    if result:
        print("✓ Table 'property_listings' exists")
    else:
        print("⚠ Table does not exist - run database setup first")
    
except Exception as e:
    print(f"⚠ Database connection failed: {e}")
    print("Note: Ensure MySQL is running and db_credentials.py is configured")
# Out:
# INFO:db_connector:Successfully connected to MySQL Server version 8.0.46
# INFO:db_connector:Connected to database: yay_studios_real_estate
# ERROR:db_connector:Error executing query: Unread result found
# ✓ Database connection successful!
# ⚠ Table does not exist - run database setup first

# %% [markdown]
# ## Step 3: Database Connection & Data Import

# %%
# Clean the data
preprocessor = DataPreprocessor(df)
df_clean = preprocessor.load_and_clean()

print(f"Data cleaned successfully!")
print(f"Final shape: {df_clean.shape}")
print(f"\nColumn info:")
print(df_clean.info())
# Out:
# INFO:data_preprocessing:Original dataset shape: (13320, 9)
# INFO:data_preprocessing:After removing duplicates: (12791, 9)
# d:\learning\hsh2\final_project\DataScienceProjekt\notebooks\../src\data_preprocessing.py:45: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   self.df[col].fillna(self.df[col].median(), inplace=True)
# ...

# %% [markdown]
# ## Step 2: Data Cleaning

# %%
# Load the CSV data
csv_path = '../data/raw/Bengaluru_House_Data.csv'
df = load_csv(csv_path)

print(f"Dataset loaded successfully!")
print(f"Shape: {df.shape}")
print(f"\nFirst few rows:")
print(df.head())
# Out:
# Dataset loaded successfully!
# Shape: (13320, 9)
#
# First few rows:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %% [markdown]
# ## Step 1: Load Data from CSV

# %%
import pandas as pd
import numpy as np
import sys
import os

# Add src to path
sys.path.insert(0, '../src')

from data_preprocessing import DataPreprocessor, load_csv
from db_connector import MySQLConnector

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # 1. Data Import & Database Setup
# Bengaluru House Price Prediction - Data Loading and MySQL Integration
