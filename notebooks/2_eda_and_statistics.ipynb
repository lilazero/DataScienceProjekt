# %%
print("\n" + "=" * 70)
print("DATA QUALITY REPORT")
print("=" * 70)
print(f"\n✓ Total Records: {len(df_clean):,}")
print(f"✓ Total Features: {len(df_clean.columns)}")
print(f"✓ Numeric Features: {len(numeric_df.columns)}")
print(f"✓ Categorical Features: {len(categorical_cols)}")
print(f"✓ Memory Usage: {df_clean.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

print("\n✓ EDA completed successfully!")
print("\nKey Findings:")
print("  - Dataset is ready for model training")
print("  - No critical missing values")
print("  - Price range suitable for regression modeling")
# Out:
# ======================================================================
# DATA QUALITY REPORT
# ======================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 print("\n" + "=" * 70)
#       2 print("DATA QUALITY REPORT")
#       3 print("=" * 70)
# ----> 4 print(f"\n✓ Total Records: {len(df_clean):,}")
#       5 print(f"✓ Total Features: {len(df_clean.columns)}")
#       6 print(f"✓ Numeric Features: {len(numeric_df.columns)}")
#       7 print(f"✓ Categorical Features: {len(categorical_cols)}")
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ## Step 6: Data Quality Summary

# %%
# Categorical columns analysis
categorical_cols = df_clean.select_dtypes(include=['object']).columns

print("=" * 70)
print("CATEGORICAL FEATURES")
print("=" * 70)

for col in categorical_cols[:3]:  # Show first 3
    print(f"\n{col}:")
    print(f"  Unique values: {df_clean[col].nunique()}")
    print(f"  Top 5:")
    print(df_clean[col].value_counts().head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Categorical columns analysis
# ----> 2 categorical_cols = df_clean.select_dtypes(include=['object']).columns
#       3
#       4 print("=" * 70)
#       5 print("CATEGORICAL FEATURES")
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ## Step 5: Categorical Analysis

# %%
# Correlation matrix
numeric_df = df_clean.select_dtypes(include=[np.number])
if len(numeric_df.columns) > 1:
    corr_matrix = numeric_df.corr()
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, 
                fmt='.2f', cbar_kws={'label': 'Correlation'})
    plt.title('Correlation Matrix - Numeric Features')
    plt.tight_layout()
    plt.show()
    
    # Find correlations with price (if exists)
    if 'price' in corr_matrix.columns:
        price_corr = corr_matrix['price'].sort_values(ascending=False)
        print("\nCorrelation with Price:")
        print(price_corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Correlation matrix
# ----> 2 numeric_df = df_clean.select_dtypes(include=[np.number])
#       3 if len(numeric_df.columns) > 1:
#       4     corr_matrix = numeric_df.corr()
#       5
#
# NameError: name 'df_clean' is not defined

# %% [markdown]
# ## Step 4: Correlation Analysis

# %%
# Price distribution
if 'price' in df_clean.columns:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Histogram
    axes[0].hist(df_clean['price'], bins=50, edgecolor='black', color='skyblue')
    axes[0].set_xlabel('Price')
    axes[0].set_ylabel('Frequency')
    axes[0].set_title('Price Distribution')
    axes[0].grid(True, alpha=0.3)
    
    # Box plot
    axes[1].boxplot(df_clean['price'])
    axes[1].set_ylabel('Price')
    axes[1].set_title('Price Box Plot')
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    print(f"\nPrice Statistics:")
    print(f"  Mean: {df_clean['price'].mean():.2f}")
    print(f"  Median: {df_clean['price'].median():.2f}")
    print(f"  Std Dev: {df_clean['price'].std():.2f}")
    print(f"  Min: {df_clean['price'].min():.2f}")
    print(f"  Max: {df_clean['price'].max():.2f}")

# %% [markdown]
# ## Step 3: Distribution Analysis

# %%
# Descriptive statistics
print("=" * 70)
print("DESCRIPTIVE STATISTICS - NUMERIC COLUMNS")
print("=" * 70)
numeric_stats = df_clean.describe()
print(numeric_stats)

print("\n" + "=" * 70)
print("MISSING VALUES")
print("=" * 70)
missing = df_clean.isnull().sum()
if missing.sum() > 0:
    print(missing[missing > 0])
else:
    print("✓ No missing values")
# Out:
# ======================================================================
# DESCRIPTIVE STATISTICS - NUMERIC COLUMNS
# ======================================================================
#          total_sqft          bath       balcony         price
# count  12791.000000  12791.000000  12791.000000  12791.000000
# mean    1559.503348      2.704558      1.602064    114.317646
# std     1248.705788      1.354936      0.807728    151.480310
# min        1.000000      1.000000      0.000000      8.000000
# 25%     1100.000000      2.000000      1.000000     50.000000
# 50%     1280.000000      2.000000      2.000000     73.000000
# 75%     1672.000000      3.000000      2.000000    121.000000
# max    52272.000000     40.000000      3.000000   3600.000000
#
# ======================================================================
# MISSING VALUES
# ======================================================================
# location       1
# size          16
# society     5328
# dtype: int64

# %% [markdown]
# ## Step 2: Descriptive Statistics

# %%
# Load and clean data
df = load_csv('../data/raw/Bengaluru_House_Data.csv')
preprocessor = DataPreprocessor(df)
df_clean = preprocessor.load_and_clean()
print(f"Data loaded and cleaned: {df_clean.shape}")
# Out:
# INFO:data_preprocessing:Original dataset shape: (13320, 9)
# INFO:data_preprocessing:After removing duplicates: (12791, 9)
# d:\learning\hsh2\final_project\DataScienceProjekt\notebooks\../src\data_preprocessing.py:45: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   self.df[col].fillna(self.df[col].median(), inplace=True)
# d:\learning\hsh2\final_project\DataScienceProjekt\notebooks\../src\data_preprocessing.py:45: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   self.df[col].fillna(self.df[col].median(), inplace=True)
# d:\learning\hsh2\final_project\DataScienceProjekt\notebooks\../src\data_preprocessing.py:51: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   self.df[col].fillna(self.df[col].mode()[0] if len(self.df[col].mode()) > 0 else 'Unknown', inplace=True)
# INFO:data_preprocessing:Missing values handled. Remaining NaN: 6023
# INFO:data_preprocessing:Final cleaned shape: (12791, 9)
# Data loaded and cleaned: (12791, 9)

# %% [markdown]
# ## Step 1: Load and Clean Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.insert(0, '../src')

from data_preprocessing import DataPreprocessor, load_csv

# Configuration
pd.set_option('display.max_columns', None)
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # 2. Exploratory Data Analysis & Statistics
# Statistical analysis, distributions, correlations, and data quality assessment
